# %% [markdown]
# # Analysis of Flipkart data

# %% [markdown]
# ### A project by Kaushik,Mukund,Rajdeep,Salini , Batch 3, GLobsyn Machine Learning with Python 2018 Summer School

# %% [markdown]
# ### Determine the specifications keys corresponding to each product category from the product_specifications column

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('flipkart_spec_cat_brand.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                           product_name  \
# 0           0             0    Alisha Solid Women's Cycling Shorts
# 1           1             1    FabHomeDecor Fabric Double Sofa Bed
# 2           2             2                             AW Bellies
# 3           3             3    Alisha Solid Women's Cycling Shorts
# 4           4             4  Sicons All Purpose Arnica Dog Shampoo
#
#                                product_category_tree  retail_price  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...         999.0
# 1  ["Furniture >> Living Room Furniture >> Sofa B...       32157.0
# 2  ["Footwear >> Women's Footwear >> Ballerinas >...         999.0
# 3  ["Clothing >> Women's Clothing >> Lingerie, Sl...         699.0
# 4  ["Pet Supplies >> Grooming >> Skin & Coat Care...         220.0
#
#    discounted_price  is_FK_Advantage_product       product_rating  \
# 0             379.0                    False  No rating available
# ...

# %%
df2 = df.columns.get_values()
df2[0] = 'not_req'
df2[1] = 'not_req2'

# %%
df.columns = df2

# %%
df.head(1)
# Out:
#    not_req  not_req2                         product_name  \
# 0        0         0  Alisha Solid Women's Cycling Shorts
#
#                                product_category_tree  retail_price  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...         999.0
#
#    discounted_price  is_FK_Advantage_product       product_rating  \
# 0             379.0                    False  No rating available
#
#         overall_rating Brand_names product_category  \
# 0  No rating available      Alisha        Clothing
#
#                                product_specs_refined
# 0  {"product_specification"=>[{"key"=>"Number of ...

# %%
df.drop(['not_req','not_req2','product_name','product_category_tree','discounted_price'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    retail_price  is_FK_Advantage_product       product_rating  \
# 0         999.0                    False  No rating available
# 1       32157.0                    False  No rating available
# 2         999.0                    False  No rating available
# 3         699.0                    False  No rating available
# 4         220.0                    False  No rating available
#
#         overall_rating   Brand_names product_category  \
# 0  No rating available        Alisha        Clothing
# 1  No rating available  FabHomeDecor       Furniture
# 2  No rating available            AW        Footwear
# 3  No rating available        Alisha        Clothing
# 4  No rating available        Sicons    Pet Supplies
#
#                                product_specs_refined
# 0  {"product_specification"=>[{"key"=>"Number of ...
# 1  {"product_specification"=>[{"key"=>"Installati...
# 2  {"product_specification"=>[{"key"=>"Ideal For"...
# 3  {"product_specification"=>[{"key"=>"Number of ...
# ...

# %%
df.drop(['retail_price','is_FK_Advantage_product','product_rating','overall_rating','Brand_names'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   product_category                              product_specs_refined
# 0        Clothing   {"product_specification"=>[{"key"=>"Number of ...
# 1       Furniture   {"product_specification"=>[{"key"=>"Installati...
# 2        Footwear   {"product_specification"=>[{"key"=>"Ideal For"...
# 3        Clothing   {"product_specification"=>[{"key"=>"Number of ...
# 4    Pet Supplies   {"product_specification"=>[{"key"=>"Pet Type",...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19441 entries, 0 to 19440
# Data columns (total 2 columns):
# product_category         19441 non-null object
# product_specs_refined    19441 non-null object
# dtypes: object(2)
# memory usage: 151.9+ KB

# %%
df['product_category'][6000] in df['product_specs_refined'][6000]
# Out:
# False

# %%
df['product_category'][4000]
# Out:
# 'Kitchen & Dining '

# %%
x = df['product_specs_refined'][4000]

# %%
x
# Out:
# '{"product_specification"=>[{"key"=>"Pan Type", "value"=>"Chetty"}, {"key"=>"Non-stick", "value"=>"Yes"}, {"key"=>"Brand", "value"=>"Kumkum"}, {"key"=>"Model Number", "value"=>"KK110"}, {"key"=>"Induction Bottom", "value"=>"No"}, {"key"=>"Type", "value"=>"Kadhai"}, {"key"=>"Material", "value"=>"Aluminium"}, {"key"=>"Model Name", "value"=>"Nonstick Deep"}, {"key"=>"Lid Included", "value"=>"Yes"}, {"key"=>"Capacity", "value"=>"3 L"}, {"key"=>"Color", "value"=>"Red, Black"}, {"key"=>"Sales Package", "value"=>"1 Deep Kadhai With Lid"}, {"key"=>"Pack of", "value"=>"1"}, {"key"=>"Diameter", "value"=>"35 cm"}, {"key"=>"Weight", "value"=>"700 g"}]}'

# %%
x.index('key')
# Out:
# 29

# %%
x = x[36:]

# %%
x
# Out:
# 'Pan Type", "value"=>"Chetty"}, {"key"=>"Non-stick", "value"=>"Yes"}, {"key"=>"Brand", "value"=>"Kumkum"}, {"key"=>"Model Number", "value"=>"KK110"}, {"key"=>"Induction Bottom", "value"=>"No"}, {"key"=>"Type", "value"=>"Kadhai"}, {"key"=>"Material", "value"=>"Aluminium"}, {"key"=>"Model Name", "value"=>"Nonstick Deep"}, {"key"=>"Lid Included", "value"=>"Yes"}, {"key"=>"Capacity", "value"=>"3 L"}, {"key"=>"Color", "value"=>"Red, Black"}, {"key"=>"Sales Package", "value"=>"1 Deep Kadhai With Lid"}, {"key"=>"Pack of", "value"=>"1"}, {"key"=>"Diameter", "value"=>"35 cm"}, {"key"=>"Weight", "value"=>"700 g"}]}'

# %%
x.index('"')
# Out:
# 8

# %%
y = x[:8]
print(y)
# Out:
# Pan Type

# %%
x = x[8:]
x
# Out:
# '", "value"=>"Chetty"}, {"key"=>"Non-stick", "value"=>"Yes"}, {"key"=>"Brand", "value"=>"Kumkum"}, {"key"=>"Model Number", "value"=>"KK110"}, {"key"=>"Induction Bottom", "value"=>"No"}, {"key"=>"Type", "value"=>"Kadhai"}, {"key"=>"Material", "value"=>"Aluminium"}, {"key"=>"Model Name", "value"=>"Nonstick Deep"}, {"key"=>"Lid Included", "value"=>"Yes"}, {"key"=>"Capacity", "value"=>"3 L"}, {"key"=>"Color", "value"=>"Red, Black"}, {"key"=>"Sales Package", "value"=>"1 Deep Kadhai With Lid"}, {"key"=>"Pack of", "value"=>"1"}, {"key"=>"Diameter", "value"=>"35 cm"}, {"key"=>"Weight", "value"=>"700 g"}]}'

# %%
key_count = x.count('key')

# %%
key_count
# Out:
# 14

# %%
x = df['product_specs_refined'][4000]

# %%
keys = []
key_count = x.count('key')
for i in range(key_count):
    m = x.index('key')
    x = x[m+7:]
    m = x.index('"')
    y = x[:m]
    x = x[m:]
    keys.append(y)

# %%
keys
# Out:
# ['Pan Type',
#  'Non-stick',
#  'Brand',
#  'Model Number',
#  'Induction Bottom',
#  'Type',
#  'Material',
#  'Model Name',
#  'Lid Included',
#  'Capacity',
#  'Color',
#  'Sales Package',
#  'Pack of',
#  'Diameter',
#  'Weight']

# %%
def getkey(x):
    keys = []
    key_count = x.count('key')
    for i in range(key_count):
        m = x.index('key')
        x = x[m+7:]
        m = x.index('"')
        y = x[:m]
        x = x[m:]
        keys.append(y)
    return keys

# %%
category_keys_dict = {}

# %%
for row_index,row in df.iterrows():
    try:
        category_keys_dict[row['product_category']] = getkey(row['product_specs_refined'])
    except ValueError:
        category_keys_dict[row['product_category']] = 'No keys'

# %%
category_keys_dict
# Out:
# {'883 Police Full Sleeve Solid Men\'s Jacket"': ['Sleeve',
#   'Hooded',
#   'Reversible',
#   'Fabric',
#   'Pattern',
#   'Ideal For',
#   'Style Code'],
#  'ABEEZ Boys, Men, Girls (Black, Pack of 1)"': ['Material',
#   'Adjustable',
#   'Size',
#   'Number of Contents in Sales Package',
#   'Sales Package'],
#  'ANAND ARCHIES Girls Flats"': ['Ideal For',
#   'Occasion',
#   'Sole Material',
#   'Type',
#   'Heel Height',
#   'Outer Material',
#   'Color'],
#  'ANAND ARCHIES Girls Wedges"': ['Ideal For',
#   'Occasion',
#   'Sole Material',
#   'Type',
#   'Heel Height',
#   'Outer Material',
#   'Color'],
#  'ANASAZI Casual 3/4 Sleeve Solid Women\'s Top"': ['Sleeve',
#   'Number of Contents in Sales Package',
#   'Fabric',
#   'Type',
#   'Neck',
#   'Pattern',
#   'Ideal For',
#   'Occasion'],
#  'ATV Pouch for Acer Liquid Z330 (STEEL BLUE)"': ['Brand',
#   'Shade',
#   'Material',
#   'Designed for',
#   'Model ID',
#   'Color',
#   'Sales Package'],
# ...

# %%
df.head(1)
# Out:
#   product_category                              product_specs_refined
# 0        Clothing   {"product_specification"=>[{"key"=>"Number of ...

# %%
categories = category_keys_dict.keys()
type(categories)
categories = list(categories)

# %%
categories
# Out:
# ['Clothing ',
#  'Furniture ',
#  'Footwear ',
#  'Pet Supplies ',
#  'Eternal Gandhi Super Series Crystal Paper Weight..."',
#  'Pens & Stationery ',
#  'Bengal Blooms Rose Artificial Plant  with Pot (3..."',
#  'Bags, Wallets & Belts ',
#  'Home Decor & Festive Needs ',
#  'Automotive ',
#  'Tools & Hardware ',
#  'Vishudh Printed Women\'s Straight Kurta"',
#  'Vishudh Printed Women\'s Anarkali Kurta"',
#  'BuildTrack PIR Wireless Motion Sensor - One Swit..."',
#  'Skayvon SUMMERSIBLE SINGLE PHASE PUMP CONTROLLER..."',
#  'MASARA Solid Women\'s Straight Kurta"',
#  'Skayvon SUBMERSIBBLE THREE PHASE PUMP CONTROLLER..."',
#  'Behringer Xenyx 502 Analog Sound Mixer"',
#  'Noor Embroidered Women\'s Straight Kurta"',
#  'Libas Printed Women\'s A-line Kurta"',
#  'Libas Printed Women\'s Anarkali Kurta"',
#  'Sports & Fitness ',
#  'Home Furnishing ',
#  'Baby Care ',
#  'Mobiles & Accessories ',
#  'Food & Nutrition ',
#  'Toys & School Supplies ',
#  'Jewellery ',
# ...

# %%
keys = category_keys_dict.values()
type(keys)
keys = list(keys)

# %%
keys
# Out:
# [['Pattern', 'Pattern', 'Occasion', 'Ideal For', 'Sleeve', 'Fabric'],
#  ['Foldable',
#   'Brand',
#   'Delivery Condition',
#   'Type',
#   'Style',
#   'Seating Capacity',
#   'Upholstery Type',
#   'Upholstery Included',
#   'Suitable For',
#   'Model Number',
#   'Armrest Included',
#   'Finish Type',
#   'Care Instructions',
#   'Weight',
#   'Height',
#   'Width',
#   'Depth',
#   'Covered in Warranty',
#   'Warranty Summary',
#   'Service Type',
#   'Not Covered in Warranty',
#   'Primary Material',
#   'Primary Color',
#   'Upholstery Color',
#   'Secondary Material',
#   'Secondary Material Subtype',
#   'Finish Color',
#   'Primary Material Subtype'],
#  ['Occasion', 'Ideal For', 'Type', 'Heel Height', 'Outer Material', 'Color'],
#  ['Pet Type',
#   'Body Material',
#   'Brand',
#   'Shape',
#   'Suitable For',
#   'Model Number',
#   'Shade',
#   'Type',
#   'Finish',
#   'Capacity',
#   'Size',
#   'Color',
#   'Height',
#   'Width',
#   'Depth'],
# ...

# %%
dfkeyscategories = pd.DataFrame(categories)

# %%
dfkeyscategories['Specification_keys'] = keys

# %%
dfkeyscategories.columns = ['Category','Specification_keys']

# %%
dfkeyscategories.head(3)
# Out:
#      Category                                 Specification_keys
# 0   Clothing   [Pattern, Pattern, Occasion, Ideal For, Sleeve...
# 1  Furniture   [Foldable, Brand, Delivery Condition, Type, St...
# 2   Footwear   [Occasion, Ideal For, Type, Heel Height, Outer...

# %% [markdown]
# ### Create lists of specification value pairs for each product. The keys should be determined by the product category of that product

# %%
df.head()
# Out:
#   product_category                              product_specs_refined
# 0        Clothing   {"product_specification"=>[{"key"=>"Number of ...
# 1       Furniture   {"product_specification"=>[{"key"=>"Installati...
# 2        Footwear   {"product_specification"=>[{"key"=>"Ideal For"...
# 3        Clothing   {"product_specification"=>[{"key"=>"Number of ...
# 4    Pet Supplies   {"product_specification"=>[{"key"=>"Pet Type",...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19441 entries, 0 to 19440
# Data columns (total 2 columns):
# product_category         19441 non-null object
# product_specs_refined    19441 non-null object
# dtypes: object(2)
# memory usage: 151.9+ KB

# %%
x = df['product_specs_refined'][4000]
x
# Out:
# '{"product_specification"=>[{"key"=>"Pan Type", "value"=>"Chetty"}, {"key"=>"Non-stick", "value"=>"Yes"}, {"key"=>"Brand", "value"=>"Kumkum"}, {"key"=>"Model Number", "value"=>"KK110"}, {"key"=>"Induction Bottom", "value"=>"No"}, {"key"=>"Type", "value"=>"Kadhai"}, {"key"=>"Material", "value"=>"Aluminium"}, {"key"=>"Model Name", "value"=>"Nonstick Deep"}, {"key"=>"Lid Included", "value"=>"Yes"}, {"key"=>"Capacity", "value"=>"3 L"}, {"key"=>"Color", "value"=>"Red, Black"}, {"key"=>"Sales Package", "value"=>"1 Deep Kadhai With Lid"}, {"key"=>"Pack of", "value"=>"1"}, {"key"=>"Diameter", "value"=>"35 cm"}, {"key"=>"Weight", "value"=>"700 g"}]}'

# %%
x.index('value')
# Out:
# 48

# %%
x = x[57:]
x
# Out:
# 'Chetty"}, {"key"=>"Non-stick", "value"=>"Yes"}, {"key"=>"Brand", "value"=>"Kumkum"}, {"key"=>"Model Number", "value"=>"KK110"}, {"key"=>"Induction Bottom", "value"=>"No"}, {"key"=>"Type", "value"=>"Kadhai"}, {"key"=>"Material", "value"=>"Aluminium"}, {"key"=>"Model Name", "value"=>"Nonstick Deep"}, {"key"=>"Lid Included", "value"=>"Yes"}, {"key"=>"Capacity", "value"=>"3 L"}, {"key"=>"Color", "value"=>"Red, Black"}, {"key"=>"Sales Package", "value"=>"1 Deep Kadhai With Lid"}, {"key"=>"Pack of", "value"=>"1"}, {"key"=>"Diameter", "value"=>"35 cm"}, {"key"=>"Weight", "value"=>"700 g"}]}'

# %%
x.index('"')
# Out:
# 6

# %%
x[:6]
# Out:
# 'Chetty'

# %%
x[6:]
# Out:
# '"}, {"key"=>"Non-stick", "value"=>"Yes"}, {"key"=>"Brand", "value"=>"Kumkum"}, {"key"=>"Model Number", "value"=>"KK110"}, {"key"=>"Induction Bottom", "value"=>"No"}, {"key"=>"Type", "value"=>"Kadhai"}, {"key"=>"Material", "value"=>"Aluminium"}, {"key"=>"Model Name", "value"=>"Nonstick Deep"}, {"key"=>"Lid Included", "value"=>"Yes"}, {"key"=>"Capacity", "value"=>"3 L"}, {"key"=>"Color", "value"=>"Red, Black"}, {"key"=>"Sales Package", "value"=>"1 Deep Kadhai With Lid"}, {"key"=>"Pack of", "value"=>"1"}, {"key"=>"Diameter", "value"=>"35 cm"}, {"key"=>"Weight", "value"=>"700 g"}]}'

# %%
def getvalues(x):
    values = []
    value_count = x.count('value')
    for i in range(value_count):
        m = x.index('value')
        x = x[m+9:]
        m = x.index('"')
        y = x[:m]
        x = x[m:]
        values.append(y)
    return values

# %%
category_values_dict = {}
for row_index,row in df.iterrows():
    try:
        category_values_dict[row['product_category']] = getvalues(row['product_specs_refined'])
    except ValueError:
        category_values_dict[row['product_category']] = 'No values'

# %%
category_values_dict
# Out:
# {'883 Police Full Sleeve Solid Men\'s Jacket"': ['Full Sleeve',
#   'No',
#   'No',
#   'Polyester',
#   'Solid',
#   "Men's",
#   'Jacket',
#   'CORBET16A-BLACK',
#   'Wash with Similar Colors, Use Detergent for Colors'],
#  'ABEEZ Boys, Men, Girls (Black, Pack of 1)"': ['SILICONE RUBBER',
#   'Yes',
#   'One Size Fit For All',
#   'Pack of 1',
#   '1wrist band'],
#  'ANAND ARCHIES Girls Flats"': ['Girls',
#   'Casual',
#   'PU',
#   'Flats',
#   '1 inch',
#   'Artificial Leather',
#   'PINK',
#   '2 Sandals'],
#  'ANAND ARCHIES Girls Wedges"': ['Girls',
#   'Casual',
#   'PU',
#   'Wedges',
#   '2 inch',
#   'Artificial Leather',
#   'GOLD',
#   '2 Wedges'],
#  'ANASAZI Casual 3/4 Sleeve Solid Women\'s Top"': ['3/4 Sleeve',
#   'Pack of 1',
#   'COTTON',
#   'Top',
#   'Round Neck',
#   'Solid',
#   "Women's",
#   'Casual',
#   'Gentle Machine Wash',
#   'Top'],
#  'ATV Pouch for Acer Liquid Z330 (STEEL BLUE)"': ['ATV',
#   'STEEL BLUE',
#   'Artificial Leather',
# ...

# %%
df_keys_values = dfkeyscategories.copy()

# %%
df_keys_values.head()
# Out:
#                                             Category  \
# 0                                          Clothing
# 1                                         Furniture
# 2                                          Footwear
# 3                                      Pet Supplies
# 4  Eternal Gandhi Super Series Crystal Paper Weig...
#
#                                   Specification_keys
# 0  [Pattern, Pattern, Occasion, Ideal For, Sleeve...
# 1  [Foldable, Brand, Delivery Condition, Type, St...
# 2  [Occasion, Ideal For, Type, Heel Height, Outer...
# 3  [Pet Type, Body Material, Brand, Shape, Suitab...
# 4  [Model Name, Weight, Paper Weight Material, Pa...

# %%
values = list(category_values_dict.values())

# %%
values
# Out:
# [['Solid',
#   'Solid',
#   'Casual',
#   "Women's",
#   'Full Sleeve',
#   'Cotton',
#   '2 Shrug',
#   'Wash with Similar Colors'],
#  ['1 Kids Table 1 Kids Chair',
#   'The color of some product parts may vary from what is shown in the image',
# ...

# %%
category_list = list(category_values_dict.keys())

# %%
df_keys_values['Specification_values'] = values

# %%
df_keys_values.tail(2)
# Out:
#         Category                                 Specification_keys  \
# 264  Sunglasses"  [Style, Style Code, Ideal For, Usage, Size, Co...
# 265      eBooks   [Publisher, Publication Date, ISBN, File Size,...
#
#                                   Specification_values
# 264  [Wayfarer, BLKREDGRADGRY, Men, Women, Eye Prot...
# 265  [Elsevier Science, 2012-12-31, 9780123947888, ...

# %%
for row_index,row in df_keys_values.iterrows():
    df_keys_values['Specification_values'][row_index] = category_values_dict[row['Category']]

# %%
df_keys_values.head()
# Out:
#                                             Category  \
# 0                                          Clothing
# 1                                         Furniture
# 2                                          Footwear
# 3                                      Pet Supplies
# 4  Eternal Gandhi Super Series Crystal Paper Weig...
#
#                                   Specification_keys  \
# 0  [Pattern, Pattern, Occasion, Ideal For, Sleeve...
# 1  [Foldable, Brand, Delivery Condition, Type, St...
# 2  [Occasion, Ideal For, Type, Heel Height, Outer...
# 3  [Pet Type, Body Material, Brand, Shape, Suitab...
# 4  [Model Name, Weight, Paper Weight Material, Pa...
#
#                                 Specification_values
# 0  [Solid, Solid, Casual, Women's, Full Sleeve, C...
# 1  [1 Kids Table 1 Kids Chair, The color of some ...
# 2  [Party, Women, Heels, 3 inch, Synthetic Leathe...
# 3  [Bird, Stainless Steel, Pawzone, Round, Adult,...
# 4  [Gandhi Paper Weight Mark V, 323 g, Paper Weig...

# %%
df_keys_values.to_csv('flipkart_keys_values.csv',encoding='utf-8')

# %% [markdown]
# ## Applying product specifications values to all the products

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19441 entries, 0 to 19440
# Data columns (total 2 columns):
# product_category         19441 non-null object
# product_specs_refined    19441 non-null object
# dtypes: object(2)
# memory usage: 151.9+ KB

# %%
df['Product_specifications_values'] = np.random.random(19441)

# %%
for row_index,row in df.iterrows():
    try:
        df['Product_specifications_values'][row_index] = getvalues(row['product_specs_refined'])
    except ValueError:
        df['Product_specifications_values'][row_index] = 'No Values'
# Out:
# C:\Users\h_asp\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\h_asp\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df.head()
# Out:
#   product_category                              product_specs_refined  \
# 0        Clothing   {"product_specification"=>[{"key"=>"Number of ...
# 1       Furniture   {"product_specification"=>[{"key"=>"Installati...
# 2        Footwear   {"product_specification"=>[{"key"=>"Ideal For"...
# 3        Clothing   {"product_specification"=>[{"key"=>"Number of ...
# 4    Pet Supplies   {"product_specification"=>[{"key"=>"Pet Type",...
#
#                        Product_specifications_values
# 0  [Pack of 3, Cotton Lycra, Cycling Shorts, Soli...
# 1  [Installation and demo for this product is don...
# 2  [Women, Casual, Red, Patent Leather, 1 inch, P...
# 3  [Pack of 2, Cotton Lycra, Cycling Shorts, Soli...
# 4  [Dog, Sicons, 500 ml, SH.DF-14, All Purpose, A...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19441 entries, 0 to 19440
# Data columns (total 3 columns):
# product_category                 19441 non-null object
# product_specs_refined            19441 non-null object
# Product_specifications_values    19441 non-null object
# dtypes: object(3)
# memory usage: 227.9+ KB

# %%
#df.drop(['product_specs_refined'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19441 entries, 0 to 19440
# Data columns (total 3 columns):
# product_category                 19441 non-null object
# product_specs_refined            19441 non-null object
# Product_specifications_values    19441 non-null object
# dtypes: object(3)
# memory usage: 227.9+ KB

# %%
df.to_csv('flipkart_spec_values_category_2.csv',encoding='utf-8')

# %%
#for row_index,row in df.iterrows():
#    try:
#        df['Product_specifications_values'][row_index] = getvalues(row['product_specs_refined'])
#    except ValueError:
#        df['Product_specifications_values'][row_index] = 'No Values'

# %%
#df_values = pd.read_csv('flipkart_final_cleared.csv')

# %%
#df_values['specifications_values'] = np.random.random(19441)

# %%
#for row_index,row in df_values.iterrows():
#    try:
#        df_values['specifications_values'][row_index] = getvalues(row['product_specs_refined'])
#    except ValueError:
#        df_values['specifications_values'][row_index] = 'No Values'
